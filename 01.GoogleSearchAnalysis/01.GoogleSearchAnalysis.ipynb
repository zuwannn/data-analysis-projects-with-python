# %% [markdown]
# ## คำอธิบาย
#     วิเคราะห์ข้อมมูลตามคำค้นหาโดยgoogle ด้วย python ในที่นี้คำที่จะค้นหาคือคำว่า "Machine Learning"
#     - แสดงข้อมูล 10 ประเทศสูงสุด ที่ค้นหาคำนี้
#     - นำข้อมูลไปสร้าง Bar Chart และ trands

# %% [markdown]
# ### Import libraries

# %% [markdown]
# fist of all we need install pytrends
# https://pypi.org/project/pytrends/

# %%
import pandas as pd 
from pytrends.request import TrendReq
import matplotlib.pyplot as plt
trends = TrendReq()

# %% [markdown]
# create Dataframe of the top 10 countries

# %%
trends.build_payload(kw_list=["Machine Learning"])
data = trends.interest_by_region()
data = data.sort_values(by="Machine Learning", ascending=False)
data = data.head(10)
print(data)
# Out:
#              Machine Learning
# geoName
# China                     100
# Singapore                  37
# St. Helena                 27
# India                      27
# Hong Kong                  22
# Ethiopia                   22
# South Korea                21
# Nepal                      18
# Pakistan                   17
# Tunisia                    16

# %% [markdown]
# visualize using bar chart

# %%
data.reset_index().plot(x="geoName", y="Machine Learning",
                        figsize=(20,15), kind="bar")
plt.style.use('fivethirtyeight')
plt.show()

# %% [markdown]
# trand of search queries (increases or decreased on google)

# %%
data = TrendReq(hl='en-US', tz=360)
data.build_payload(kw_list=['Machine Learning'])
data = data.interest_over_time()
fig, ax = plt.subplots(figsize=(20, 15))
data['Machine Learning'].plot()
plt.style.use('fivethirtyeight')
plt.title('Total Google Searches for Machine Learning', fontweight='bold')
plt.xlabel('Year')
plt.ylabel('total Count')
plt.show()
